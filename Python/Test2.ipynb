# %%
import pandas as pd

# %%
new=pd.read_excel(r"C:\Users\justw\Downloads\Python\Global_Superstore.xlsx")

# %%
new
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
new1=pd.read_excel(r"C:\Users\justw\Downloads\Python\Global_Superstore.xlsx",sheet_name='Orders')
new1
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
new2=pd.read_excel(r"C:\Users\justw\Downloads\Python\Global_Superstore.xlsx",sheet_name='Return')
new2
# Out:
#                       Order_ID Returned           Region
# 0     CA-2012-SA20830140-41210      Yes       Central US
# 1     IN-2012-PB19210127-41259      Yes     Eastern Asia
# 2     CA-2012-SC20095140-41174      Yes       Central US
# 3       IN-2015-JH158207-42140      Yes          Oceania
# 4       IN-2014-LC168857-41747      Yes          Oceania
# ...                        ...      ...              ...
# 1074   IN-2014-DA1345058-41769      Yes    Southern Asia
# 1075  US-2013-HG14845140-41530      Yes       Eastern US
# 1076   US-2013-SJ2021582-41543      Yes  Central America
# 1077  CA-2015-EB13870140-42269      Yes       Eastern US
# 1078    EG-2014-PM894038-41846      Yes     North Africa
#
# [1079 rows x 3 columns]

# %% [markdown]
# # 2

# %%
d=pd.merge(new1,new2, on='Order_ID',how='inner')

# %%
a=pd.merge(new1,new2, on='Order_ID',how='outer')

# %%
b=pd.merge(new1,new2, on='Order_ID',how='left')

# %%
c=pd.merge(new1,new2, on='Order_ID',how='right')

# %%
Final_Data=pd.concat([d,a,b,c],ignore_index=True)
Final_Data
# Out:
#         Row ID                  Order_ID Order Date  Ship Date  \
# 0        30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 1        30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 2        30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 3        30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 4        30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# ...        ...                       ...        ...        ...
# 107015   28736   IN-2014-DA1345058-41769 2014-05-10 2014-05-15
# 107016   37649  US-2013-HG14845140-41530 2013-09-13 2013-09-19
# 107017      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29
# 107018   36053  CA-2015-EB13870140-42269 2015-09-22 2015-09-26
# 107019   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30
#
#              Ship Mode   Customer ID   Customer Name      Segment  \
# 0          First Class   PB-19210127  Phillip Breyer    Corporate
# 1          First Class   PB-19210127  Phillip Breyer    Corporate
# ...

# %% [markdown]
# # 3

# %%
Final_Data.loc[(Final_Data.Category=='Techonology') & (Final_Data.Sub_Category=='Phones')]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order_ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Postal Code, City, State, Country, Region_x, Market, Product_ID, Category, Sub_Category, Product_Name, Sales, Quantity, Discount, Profit, Shipping_Cost, Order_Priority, Returned, Region_y]
# Index: []
#
# [0 rows x 26 columns]

# %%
Final_Data.columns
# Out:
# Index(['Row ID', 'Order_ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region_x', 'Market', 'Product_ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order_Priority', 'Returned', 'Region_y'],
#       dtype='object')

# %% [markdown]
# # 4

# %%
Final_Data.Profit[Final_Data.Profit>0]
# Out:
# 0         720.3600
# 1         153.7500
# 2         311.8500
# 3         114.6000
# 4          68.2200
#             ...
# 107009      1.0875
# 107010      1.0200
# 107011      1.5600
# 107015      0.2400
# 107019      9.0300
# Name: Profit, Length: 79438, dtype: float64

# %% [markdown]
# # 5

# %%
Final_Data.drop_duplicates(['Order_ID'])
# Out:
#        Row ID                  Order_ID Order Date  Ship Date       Ship Mode  \
# 0       30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19     First Class
# 8       25438    IN-2015-JH158207-42140 2015-05-16 2015-05-18    Second Class
# 12      32648  CA-2014-AS10045140-41727 2014-03-29 2014-04-01     First Class
# 13      29629    IN-2014-LC168857-41747 2014-04-18 2014-04-19     First Class
# 14      30267   ID-2013-AB1001527-41439 2013-06-14 2013-06-17     First Class
# ...       ...                       ...        ...        ...             ...
# 53505    6039   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 53506   24175    IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 53507   24105   IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 53508   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 53509    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %% [markdown]
# # 6

# %%
Final_Data=Final_Data.drop(['Sales'],axis=1)

Final_Data
# Out:
#         Row ID                  Order_ID Order Date  Ship Date  \
# 0        30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 1        30190  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 2        30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 3        30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 4        30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# ...        ...                       ...        ...        ...
# 107015   28736   IN-2014-DA1345058-41769 2014-05-10 2014-05-15
# 107016   37649  US-2013-HG14845140-41530 2013-09-13 2013-09-19
# 107017      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29
# 107018   36053  CA-2015-EB13870140-42269 2015-09-22 2015-09-26
# 107019   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30
#
#              Ship Mode   Customer ID   Customer Name      Segment  \
# 0          First Class   PB-19210127  Phillip Breyer    Corporate
# 1          First Class   PB-19210127  Phillip Breyer    Corporate
# ...

# %% [markdown]
# # 7

# %%
Final_Data=Final_Data.drop(1,axis=0)
Final_Data
# Out:
#         Row ID                  Order_ID Order Date  Ship Date  \
# 0        30191  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 2        30187  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 3        30193  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 4        30189  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# 5        30194  IN-2012-PB19210127-41259 2012-12-16 2012-12-19
# ...        ...                       ...        ...        ...
# 107015   28736   IN-2014-DA1345058-41769 2014-05-10 2014-05-15
# 107016   37649  US-2013-HG14845140-41530 2013-09-13 2013-09-19
# 107017      25   US-2013-SJ2021582-41543 2013-09-26 2013-09-29
# 107018   36053  CA-2015-EB13870140-42269 2015-09-22 2015-09-26
# 107019   41315    EG-2014-PM894038-41846 2014-07-26 2014-07-30
#
#              Ship Mode   Customer ID   Customer Name      Segment  \
# 0          First Class   PB-19210127  Phillip Breyer    Corporate
# 2          First Class   PB-19210127  Phillip Breyer    Corporate
# ...
