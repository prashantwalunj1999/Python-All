# %% [markdown]
# # Outlier

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\justw\Downloads\myworkbook.xlsx")
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     float64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(6), int64(5)
# memory usage: 2.9 KB

# %% [markdown]
# # Univariate Analysis

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#one numerical variable only
ax=sns.boxplot(y=df.hp)  #for horizontal use x instead of y

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  140.628359   3.596563   3.217250
# std     6.026948   1.785922  123.938694   58.290058   0.534679   0.978457
# min    10.400000   4.000000   71.100000   58.200000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  252.220000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
df.hp.describe()
# Out:
# count     32.000000
# mean     140.628359
# std       58.290058
# min       58.200000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      252.220000
# Name: hp, dtype: float64

# %%
df
# Out:
#      mpg  cyl   disp        hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110.0000  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110.0000  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93.0000  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110.0000  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175.0000  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105.0000  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245.0000  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62.0000  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95.0000  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123.0000  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123.0000  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180.0000  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180.0000  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180.0000  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205.0000  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215.0000  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230.0000  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66.0000  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   58.2000  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65.0000  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97.0000  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150.0000  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150.0000  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245.0000  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175.0000  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66.0000  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91.0000  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113.0000  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  252.2200  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175.0000  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  146.6875  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109.0000  4.11  2.780  18.60   1   1     4     2

# %% [markdown]
# # Capping & Flooring

# %%
p1=df.hp.quantile(0.02)
p1
# Out:
# 58.2

# %%
p90=df.hp.quantile(0.98)
p90
# Out:
# 252.21999999999997

# %%
df.hp=np.where(df.hp <p1,p1, np.where(df.hp> p90,p90,df.hp))

# %%
df.hp.describe()
# Out:
# count     32.000000
# mean     140.628359
# std       58.290058
# min       58.200000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      252.220000
# Name: hp, dtype: float64

# %%
df
# Out:
#      mpg  cyl   disp        hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110.0000  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110.0000  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93.0000  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110.0000  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175.0000  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105.0000  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245.0000  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62.0000  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95.0000  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123.0000  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123.0000  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180.0000  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180.0000  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180.0000  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205.0000  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215.0000  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230.0000  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66.0000  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   58.2000  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65.0000  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97.0000  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150.0000  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150.0000  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245.0000  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175.0000  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66.0000  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91.0000  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113.0000  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  252.2200  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175.0000  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  146.6875  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109.0000  4.11  2.780  18.60   1   1     4     2

# %% [markdown]
# # Winsorizing Technique

# %%
df=pd.read_excel(r"C:\Users\justw\Downloads\myworkbook.xlsx")

# %%
sns.boxplot(y='hp',data=df)
# Out:
# <AxesSubplot:ylabel='hp'>

# %%
df.hp.describe()
# Out:
# count     32.000000
# mean     146.687500
# std       68.562868
# min       52.000000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      335.000000
# Name: hp, dtype: float64

# %%
q1=df['hp'].quantile(0.25)
q1
# Out:
# 96.5

# %%
q1=df['hp'].quantile(0.25)
q3=df['hp'].quantile(0.75)
iqr=q3-q1
Lower_limit=q1-1.5*iqr
upper_limit=q3+1.5*iqr

# %%
Lower_limit,upper_limit
# Out:
# (-28.75, 305.25)

# %%
df['hp']=np.where(df['hp']> upper_limit,upper_limit,df['hp'])

# %%
df['hp']=np.where(df['hp']> Lower_limit,Lower_limit,df['hp'])

# %%
ax=sns.boxplot(y=df["hp"])

# %%
df['hp'].describe()
# Out:
# count    32.00
# mean    -28.75
# std       0.00
# min     -28.75
# 25%     -28.75
# 50%     -28.75
# 75%     -28.75
# max     -28.75
# Name: hp, dtype: float64

# %% [markdown]
# # To Replace with Mean, Median, Mode

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_excel(r"C:\Users\justw\Downloads\myworkbook.xlsx")
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
ax=sns.boxplot(y=df["hp"])

# %%
from scipy import stats


mean=np.mean(df.hp)

median=np.median(df.hp)

mode=list(stats.mode(df.hp)[0])[0]

# %%
mean,median,mode
# Out:
# (146.6875, 123.0, 110)

# %%
df.hp=np.where(df.hp > upper_limit,mean,df.hp)

# %%
ax=sns.boxplot(y=df["hp"])

# %%
df.hp=np.where(df.hp > upper_limit,median,df.hp)

# %%
df.hp=np.where(df.hp > upper_limit, mode,df.hp)

# %% [markdown]
# #
